# %% [markdown]
# # Load data

# %%
from finance_utils.stocks.manage_data import load_data

from finance_utils.temporal_data import TemporalData

# %%
df = load_data('data.csv')

temporal_data = TemporalData(df)

# %%
tickers = temporal_data.get_company_symbols()

tickers
# Out:
# ['AMZN', 'TSLA']

# %%
var_names = temporal_data.get_var_names()

var_names
# Out:
# ['Close', 'High', 'Low', 'Open', 'Volume']

# %%
ax = temporal_data.get_swapped_df().plot(y='Close')

# %%
var_name = 'Close'
# company = 'TSLA'
company = 'AMZN'
window = 21


ma = df[company][var_name].rolling(window=window).mean()

ma.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Play with tickers

# %%
import pandas as pd
import pandas_datareader as pdr

# %%
all_stocks = pdr.nasdaq_trader.get_nasdaq_symbols()

all_stocks
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZY               True                       Zymergen Inc. - Common Stock
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %% [markdown]
# Filter stocks.

# %%
stocks = all_stocks.loc[(all_stocks['Financial Status'] == 'N') & 
                        (all_stocks['Listing Exchange'] == 'Q') &
                        (all_stocks['ETF'] == False)
]

# %%
stocks
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# AACG             True  ATA Creativity Global - American Depositary Sh...
# AACQ             True     Artius Acquisition Inc. - Class A Common Stock
# AACQU            True  Artius Acquisition Inc. - Unit consisting of o...
# AACQW            True                  Artius Acquisition Inc. - Warrant
# AAL              True       American Airlines Group, Inc. - Common Stock
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZY               True                       Zymergen Inc. - Common Stock
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %% [markdown]
# Get NASDAQ Symbol.

# %%
tickers = stocks['NASDAQ Symbol'].values.tolist()

tickers
# Out:
# ['AACG',
#  'AACQ',
#  'AACQU',
#  'AACQW',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'AAWW',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABGI',
#  'ABIO',
#  'ABMD',
#  'ABNB',
#  'ABST',
#  'ABTX',
#  'ABUS',
#  'ACAC',
#  'ACACU',
#  'ACACW',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACBAU',
#  'ACBI',
#  'ACCD',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLO',
#  'ACGLP',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACKIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACRS',
#  'ACRX',
#  'ACTC',
#  'ACTCU',
#  'ACTCW',
#  'ACTDU',
#  'ACTG',
#  'ACVA',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADER',
#  'ADERU',
#  'ADERW',
#  'ADES',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADMA',
#  'ADMP',
#  'ADMS',
#  'ADN',
#  'ADNWW',
#  'ADP',
#  'ADPT',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADXN',
#  'AEAC',
#  'AEACU',
# ...

# %% [markdown]
# # Download data

# %%
from finance_utils.stocks.manage_data import download_data

# %%
tickers = ['AMZN', 'TSLA']

interval = '1d'

# %% [markdown]
# By period.

# %%
period = '5y'
filename = 'data.csv'

df = download_data(tickers, period=period,
                   interval=interval, filename=filename)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df
# Out:
#                    AMZN                                                  \
#                    Open         High          Low        Close   Volume
# Date
# 2016-05-11   705.789978   719.000000   701.650024   713.229980  7338200
# 2016-05-12   717.380005   722.450012   711.510010   717.929993  5048200
# 2016-05-13   714.640015   719.250000   706.510010   709.919983  4763400
# 2016-05-16   710.130005   713.250000   700.280029   710.659973  5432900
# 2016-05-17   709.900024   714.469971   693.909973   695.270020  5121400
# ...                 ...          ...          ...          ...      ...
# 2021-05-04  3356.189941  3367.979980  3272.129883  3311.870117  5439400
# 2021-05-05  3338.860107  3354.699951  3264.360107  3270.540039  3711300
# 2021-05-06  3270.000000  3314.399902  3247.199951  3306.370117  4447700
# 2021-05-07  3319.090088  3330.889893  3289.070068  3291.610107  4706800
# 2021-05-10  3282.320068  3282.550049  3190.000000  3190.489990  5663738
#
#                   TSLA
# ...

# %% [markdown]
# By date.

# %%
start_date = '2016-01-01'
end_date = '2020-12-31'

df = download_data(tickers, start_date=start_date, end_date=end_date)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df
# Out:
#                   TSLA                                                \
#                   Open        High         Low       Close    Volume
# Date
# 2015-12-31   47.702000   48.689999   47.674000   48.001999  13575000
# 2016-01-04   46.144001   46.276001   43.799999   44.681999  34135500
# 2016-01-05   45.271999   45.377998   44.000000   44.686001  15934000
# 2016-01-06   44.000000   44.009998   43.195999   43.807999  18895500
# 2016-01-07   42.838001   43.688000   42.734001   43.130001  17771500
# ...                ...         ...         ...         ...       ...
# 2020-12-23  632.200012  651.500000  622.570007  645.979980  33173000
# 2020-12-24  642.989990  666.090027  641.000000  661.770020  22865600
# 2020-12-28  674.510010  681.400024  660.799988  663.690002  32278600
# 2020-12-29  661.000000  669.900024  655.000000  665.989990  22910800
# 2020-12-30  672.000000  696.599976  668.359985  694.780029  42846000
#
#                    AMZN
# ...
